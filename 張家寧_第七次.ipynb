# %% [markdown]
# <a href="https://colab.research.google.com/github/cjn002/Work-portfolio/blob/main/%E5%BC%B5%E5%AE%B6%E5%AF%A7_%E7%AC%AC%E4%B8%83%E6%AC%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 第一題：自由發揮

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
clf=SVC()

# %%
from sklearn.datasets import load_wine
wine=load_wine()
x=wine.data
x=x[:,8:10]
y=wine.target

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=111)

# %%
plt.scatter(x_train[:,0],x_train[:,1],c=y_train)

# %%
clf.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=clf.predict(x_test)

# %%
plt.scatter(x_test[:,0],x_test[:,1],c=y_pred-y_test)

# %%
#正確率
print(round(30/36,2))
# Out:
# 0.83

# %%
x2,x3=np.meshgrid(np.arange(0,4,0.02),np.arange(0,13,0.02))

# %%
zz=clf.predict(np.c_[x2.ravel(),x3.ravel()])
zz=zz.reshape(x2.shape)

# %%
plt.contourf(x2,x3,zz,cmap=plt.cm.coolwarm,alpha=0.8)
plt.scatter(x[:,0],x[:,1],c=y)
