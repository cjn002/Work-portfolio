# %% [markdown]
# <a href="https://colab.research.google.com/github/cjn002/Work-portfolio/blob/main/Python%20for%20Data%20Analysis_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 第一題：自由發揮

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
d = load_diabetes()

# %%
reg=LinearRegression()

# %%
x=d.data
y=d.target

# %%
plt.figure(figsize=(8,10))
for i,f in enumerate(d.feature_names):
  plt.subplot(4,3,i+1)
  plt.scatter(x[:,i],y,s=1)
  plt.xlabel(f)
  plt.tight_layout()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
reg.fit(x_train,y_train)
y_pred=reg.predict(x_test)
coef_df = pd.DataFrame(reg.coef_, d.feature_names, columns=['Coefficient'])
print('Intercept ',reg.intercept_)
print(coef_df)
# Out:
# Intercept  152.2555053490769
#      Coefficient
# age    -3.891552
# sex  -225.628800
# bmi   517.895254
# bp    328.321322
# s1   -727.233456
# s2    410.967994
# s3     80.266011
# s4    218.187384
# s5    704.280554
# s6     40.022472

# %%
plt.scatter(y_test,y_pred)
plt.plot([0,300],[0,300],'#888')
plt.xlabel('True')
plt.ylabel('pred.')
# Out:
# Text(0, 0.5, 'pred.')

# %%
print('x,y 相關係數')
for i,f in enumerate(d.feature_names):
  print(f, np.array(np.corrcoef(x[:,i],y)[0,1]))
# Out:
# x,y 相關係數
# age 0.18788875071891983
# sex 0.0430619984516054
# bmi 0.5864501344746891
# bp 0.4414838489308862
# s1 0.2120224810145508
# s2 0.17405358696874249
# s3 -0.39478925067091847
# s4 0.4304528847447734
# s5 0.5658834252428094
# s6 0.3824834842485812

# %%
print('R sqare =',reg.score(x_test,y_test))
# Out:
# R sqare = 0.5341962544929233
